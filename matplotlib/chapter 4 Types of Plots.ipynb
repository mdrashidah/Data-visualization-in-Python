# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# # **chapter 4: Types of Plot**

# %%
x = np.linspace(0,5,11)
x
y = x **3 
y
# Out:
# array([  0.   ,   0.125,   1.   ,   3.375,   8.   ,  15.625,  27.   ,
#         42.875,  64.   ,  91.125, 125.   ])

# %%
plt.scatter(x,y)  

# this is a scatter plot that shows individual data points without connecting them with the help of lines with dots.

# %%
plt.hist(x)
plt.xlabel('X axis')
plt.ylabel('Y axis')
# Out:
# Text(0, 0.5, 'Y axis')

# %%
plt.hist(x,y)
plt.xlabel('X axis')
# Out:
# Text(0.5, 0, 'X axis')

# %%
from random import sample 
# sample function is used to generate random samples from a given population
data = sample(range(1,1000),100) # (x-axis, y-axis)length or difference)
plt.hist(data)
# Out:
# (array([15.,  6.,  9.,  8., 11.,  6., 13., 16.,  5., 11.]),
#  array([  3., 101., 199., 297., 395., 493., 591., 689., 787., 885., 983.]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)  #nahi samaj aaya acche sein

# boxplot is
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x24874dcafd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x24874dcb250>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x24874dcae90>],
#  'medians': [<matplotlib.lines.Line2D at 0x24874dcb4d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x24874dcb610>],
#  'means': []}

# %% [markdown]
# * saving the plot

# %%
fig0 = plt.figure()
axis1 = fig0.add_axes([0.1,0.1,0.8,0.8]) 
axis1.plot(x,y)
plt.savefig("new image.jpeg") # this will save the file
