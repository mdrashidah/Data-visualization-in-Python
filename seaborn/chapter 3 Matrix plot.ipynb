# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# # ** **chapter 3 Matrix Plot** **

# %% [markdown]
# 1. Heat Map
# 2. Cluster Map
# 3. Pivot Map

# %% [markdown]
# 1. Heat Map

# %% [markdown]
# 👁 👉 Heatmap in Seaborn = a colored table that shows numbers as colors (darker/lighter = higher/lower values).
#
# So whenever you see it, just remember: “It’s like Excel cells, but instead of numbers only, the cells are shaded with colors to make patterns obvious.”

# %%
flights = sns.load_dataset('flights')
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tipscorln = tips[['total_bill','tip','size']]
tipscorln
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
tipscorln.corr() 
# this will show of the correlation matrix
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tipscorln.corr(), annot= True, cmap= 'coolwarm')

# where annot = True will show the values in the boxes
# cmap = 'coolwarm' will show the color of the boxes
# Out:
# <Axes: >

# %% [markdown]
# 2. Pivot Table

# %% [markdown]
# 👉 **Pivot Table Heatmap** = A pivot table (summary table) with colors added to show patterns, highs, and lows at a glance.
#
# Think: numbers + colors = quick insights.

# %%
pivot_flights = flights.pivot_table(index= 'month', columns= 'year', values= 'passengers')
pivot_flights
# Out:
# C:\Users\rashi\AppData\Local\Temp\ipykernel_1416\3728009159.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_flights = flights.pivot_table(index= 'month', columns= 'year', values= 'passengers')
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# ...

# %% [markdown]
# ..** **values parameter** **  specifies the column whose data will be used to fill the cells of the new table. It's the numerical data you want to summarize or aggregate. ..

# %%
sns.heatmap(pivot_flights)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# 👇🤜 for customizing the pivot table heat graph

# %%
sns.heatmap(pivot_flights, cmap= 'rainbow', linecolor= 'black', linewidths=1)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
plt.figure(figsize=(15, 10)) # You can adjust the width and height to your liking
sns.heatmap(pivot_flights, cmap= 'rainbow', linecolor= 'black', linewidth= 1, annot = True)
# Out:
# <Axes: xlabel='year', ylabel='month'>
